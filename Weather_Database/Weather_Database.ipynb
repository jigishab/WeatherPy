# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import OpenWeather_API_KEY
from citipy import citipy
import requests 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low= -180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#coordinates

# %%
# Use the print() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
    #print(coordinate[0], coordinate[1])

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    #break
# Print the city count to confirm sufficient count.
#len(cities)
cities
# Out:
# ['busselton',
#  'belushya guba',
#  'buala',
#  'kedrovyy',
#  'avarua',
#  'castro',
#  'qaanaaq',
#  'albany',
#  'atuona',
#  'ushuaia',
#  'nakamura',
#  'punta arenas',
#  'pishva',
#  'waingapu',
#  'geraldton',
#  'skibbereen',
#  'pimentel',
#  'chokurdakh',
#  'vaini',
#  'miraflores',
#  'mataura',
#  'mar del plata',
#  'puerto del rosario',
#  'rikitea',
#  'airai',
#  'kerman',
#  'mbacke',
#  'yellowknife',
#  'lavrentiya',
#  'saint george',
#  'chuy',
#  'galle',
#  'bentiu',
#  'metro',
#  'nikolskoye',
#  'faanui',
#  'pandan',
#  'heyang',
#  'cape town',
#  'arraial do cabo',
#  'yelabuga',
#  'emborion',
#  'jamestown',
#  'saskylakh',
#  'illoqqortoormiut',
#  'karkaralinsk',
#  'esperance',
#  'atasu',
#  'sola',
#  'takoradi',
#  'weligama',
#  'pampierstad',
#  'kindersley',
#  'bluff',
#  'inhambane',
#  'tuktoyaktuk',
#  'puerto cortes',
#  'brae',
#  'te anau',
#  'samusu',
#  'kungurtug',
#  'tsihombe',
#  'katangli',
#  'talnakh',
#  'beringovskiy',
#  'port alfred',
#  'pevek',
#  'lazaro cardenas',
#  'bambous virieux',
#  'killarney',
#  'pokanayevka',
#  'elliot lake',
#  'tiksi',
#  'matsubase',
#  'touros',
#  'tome',
#  'pacific grove',
#  'ixtapa',
#  'hithadhoo',
#  'the pas',
#  'odesskoye',
#  'hermanus',
#  'dingle',
#  'thompson',
#  'alexandria',
#  'chapadinha',
#  'biak',
#  'bubaque',
#  'yuxia',
#  'olinda',
#  'bredasdorp',
#  'bur gabo',
#  'puerto leguizamo',
#  'prince rupert',
#  'burica',
#  'kirakira',
#  'mahibadhoo',
#  'sao felix do xingu',
#  'barrow',
#  'cap malheureux',
#  'tiznit',
#  'butaritari',
#  'bethel',
#  'kurmanayevka',
#  'vanimo',
#  'torbay',
#  'clyde river',
#  'mason city',
#  'neepawa',
#  'hinganghat',
#  'berlevag',
#  'mys shmidta',
#  'leningradskiy',
#  'emba',
#  'severo-kurilsk',
#  'ayan',
#  'timaru',
#  'pinawa',
#  'shingu',
#  'alice springs',
#  'gua musang',
#  'tairua',
#  'dunedin',
#  'seoul',
#  'yomitan',
#  'georgetown',
#  'cherskiy',
#  'khani',
#  'maniitsoq',
#  'salalah',
#  'sungaipenuh',
#  'beipiao',
#  'hilo',
#  'sambek',
#  'mrirt',
#  'umea',
#  'reftinskiy',
#  'kaitangata',
#  'marsh harbour',
#  'banjar',
#  'micheldorf',
#  'forchheim',
#  'kawambwa',
#  'boffa',
#  'carballo',
#  'barentsburg',
#  'grand-lahou',
#  'bayangol',
#  'hatfield',
#  'bumbuna',
#  'mahasamund',
#  'taolanaro',
#  'lolua',
#  'awjilah',
#  'sortavala',
#  'katsuura',
#  'kapaa',
#  'morant bay',
#  'georgiyevka',
#  'port-gentil',
#  'puerto ayora',
#  'alta floresta',
#  'macapa',
#  'hobart',
#  'huacho',
#  'saleaula',
#  'hasaki',
#  'port hardy',
#  'guerrero negro',
#  'provideniya',
#  'atherton',
#  'shimoda',
#  'ballina',
#  'port elizabeth',
#  'yulara',
#  'longyearbyen',
#  'upernavik',
#  'souillac',
#  'elbistan',
#  'stoyba',
#  'lebu',
#  'libreville',
#  'vestmannaeyjar',
#  'misratah',
#  'port macquarie',
#  'bosaso',
#  'zhangzhou',
#  'palauig',
#  'parbhani',
#  'ponta do sol',
#  'ucluelet',
#  'new amsterdam',
#  'babanusah',
#  'sentyabrskiy',
#  'buraydah',
#  'mana',
#  'himora',
#  'amderma',
#  'new norfolk',
#  'ribeira grande',
#  'kavaratti',
#  'san joaquin',
#  'kotel',
#  'amahai',
#  'khatanga',
#  'tasiilaq',
#  'kapiri mposhi',
#  'kolpashevo',
#  'nome',
#  'nouadhibou',
#  'atambua',
#  'qasigiannguit',
#  'astana',
#  'oistins',
#  'kamenka',
#  'attawapiskat',
#  'mahebourg',
#  'la paz',
#  'sibolga',
#  'merauke',
#  'kutum',
#  'kondinskoye',
#  'palora',
#  'macia',
#  'constitucion',
#  'kodiak',
#  'kropotkin',
#  'vondrozo',
#  'malumfashi',
#  'gold coast',
#  'saint-joseph',
#  'east london',
#  'kholodnyy',
#  'osakarovka',
#  'madang',
#  'shelburne',
#  'vostok',
#  'vaitupu',
#  'oranjemund',
#  'necochea',
#  'altamira',
#  'richards bay',
#  'norman wells',
#  'flinders',
#  'port blair',
#  'dahuk',
#  'kadhan',
#  'owo',
#  'wakkanai',
#  'saldanha',
#  'kuche',
#  'korla',
#  'newcastle',
#  'noumea',
#  'tumannyy',
#  'vozhega',
#  'rakhya',
#  'ahuimanu',
#  'auki',
#  'ulladulla',
#  'tuatapere',
#  'pangai',
#  'mount isa',
#  'yuzhno-kurilsk',
#  'chyhyryn',
#  'nanortalik',
#  'ulaanbaatar',
#  'saint-philippe',
#  'luderitz',
#  'victoria',
#  'mezen',
#  'yar-sale',
#  'carnarvon',
#  'westport',
#  'huilong',
#  'maniago',
#  'sorland',
#  'fershampenuaz',
#  'iraucuba',
#  'krasnoshchekovo',
#  'narsaq',
#  'obigarm',
#  'rundu',
#  'asau',
#  'hambantota',
#  'weihe',
#  'morondava',
#  'menongue',
#  'safford',
#  'betamcherla',
#  'cabo san lucas',
#  'macamic',
#  'nemuro',
#  'dikson',
#  'yakeshi',
#  'padang',
#  'kokopo',
#  'christchurch',
#  'port lincoln',
#  'altagracia de orituco',
#  'ternate',
#  'meulaboh',
#  'felipe carrillo puerto',
#  'kiunga',
#  'lyubech',
#  'barranca',
#  'ostrovnoy',
#  'acarau',
#  'hirara',
#  'gazojak',
#  'valdivia',
#  'santa isabel do rio negro',
#  'naantali',
#  'manono',
#  'black river',
#  'shenjiamen',
#  'glenwood springs',
#  'codrington',
#  'polunochnoye',
#  'siderno',
#  'iqaluit',
#  'katima mulilo',
#  'gidam',
#  'yabelo',
#  'atbasar',
#  'north bend',
#  'sechura',
#  'kahului',
#  'waipawa',
#  'ketchikan',
#  'le port',
#  'goderich',
#  'riviere-au-renard',
#  'sept-iles',
#  'bontang',
#  'cortez',
#  'winneba',
#  'college',
#  'aykhal',
#  'bogatic',
#  'drumnadrochit',
#  'san felipe',
#  'sydney',
#  'kavieng',
#  'gamba',
#  'ajdabiya',
#  'namibe',
#  'sinnamary',
#  'gurlan',
#  'daru',
#  'gamboma',
#  'bafra',
#  'zemio',
#  'saint anthony',
#  'keetmanshoop',
#  'bury saint edmunds',
#  'otta',
#  'isangel',
#  'marrakesh',
#  'dossor',
#  'harper',
#  'seymchan',
#  'kitimat',
#  'olafsvik',
#  'aykino',
#  'klaksvik',
#  'salou',
#  'bengkulu',
#  'agen',
#  'palabuhanratu',
#  'jumla',
#  'sayyan',
#  'yeletskiy',
#  'ngaoundere',
#  'umzimvubu',
#  'cidreira',
#  'ormara',
#  'spencer',
#  'juli',
#  'dakar',
#  'west wendover',
#  'kaniama',
#  'presidencia roque saenz pena',
#  'kojnare',
#  'beyneu',
#  'at-bashi',
#  'mandera',
#  'baculin',
#  'kresttsy',
#  'hobyo',
#  'peace river',
#  'pitimbu',
#  'san fernando',
#  'yugorsk',
#  'luancheng',
#  'beloha',
#  'cockburn harbour',
#  'okazaki',
#  'akureyri',
#  'banda aceh',
#  'hellvik',
#  'ous',
#  'condega',
#  'broome',
#  'lima',
#  'karaul',
#  'palembang',
#  'sabang',
#  'tuy hoa',
#  'goundam',
#  'xining',
#  'makat',
#  'hisar',
#  'vila franca do campo',
#  'atar',
#  'avera',
#  'dwarka',
#  'nishihara',
#  'shu',
#  'castricum',
#  'bilibino',
#  'tarpon springs',
#  'walvis bay',
#  'tateyama',
#  'sumbe',
#  'borogontsy',
#  'tancanhuitz',
#  'kayasula',
#  'lata',
#  'darhan',
#  'kununurra',
#  'temaraia',
#  'taos',
#  'alofi',
#  'salme',
#  'evensk',
#  'pisco',
#  'yanan',
#  'sao joao da barra',
#  'sedelnikovo',
#  'dauphin',
#  'san quintin',
#  'iznik',
#  'townsville',
#  'tura',
#  'berezovka',
#  'blonduos',
#  'sigli',
#  'alappuzha',
#  'fortuna',
#  'aloleng',
#  'luwuk',
#  'nova granada',
#  'muros',
#  'valparaiso',
#  'gizo',
#  'taklisah',
#  'umm lajj',
#  'mata',
#  'saint-augustin',
#  'libertador general san martin',
#  'villa carlos paz',
#  'shemgang',
#  'gat',
#  'rawson',
#  'mnogovershinnyy',
#  'kendari',
#  'husavik',
#  'ust-maya',
#  'hay river',
#  'baboua',
#  'chara',
#  'hun',
#  'aitape',
#  'yaval',
#  'dubasari',
#  'japura',
#  'svetlyy',
#  'makakilo city',
#  'flin flon',
#  'rolim de moura',
#  'la ronge',
#  'vila velha',
#  'tecoanapa',
#  'oksfjord',
#  'lompoc',
#  'mount gambier',
#  'huarmey',
#  'birnin kebbi',
#  'corinto',
#  'fairbanks',
#  'kabanjahe',
#  'athabasca',
#  'yarada',
#  'cabra',
#  'macheng',
#  'barawe',
#  'suwalki',
#  'lagoa',
#  'uwayl',
#  'kantang',
#  'ozernovskiy',
#  'andarab',
#  'erzin',
#  'yumen',
#  'makungu',
#  'vao',
#  'la macarena',
#  'russell',
#  'grand gaube',
#  'barcelos',
#  'lorengau',
#  'nsanje',
#  'isla mujeres',
#  'jibuti',
#  'havre',
#  'okhotsk',
#  'louisbourg',
#  'kyshtovka',
#  'malartic',
#  'aripuana',
#  'shaikhpura',
#  'marang',
#  'fort wellington',
#  'quesnel',
#  'jacareacanga',
#  'lumut',
#  'muscat',
#  'ilhabela',
#  'bernalillo',
#  'hanna',
#  'furukawa',
#  'lenti',
#  'sarmanovo',
#  'comodoro rivadavia',
#  'ozerki',
#  'tawkar',
#  'tessalit',
#  'sioux lookout',
#  'lasa',
#  'staryy nadym',
#  'ilulissat',
#  'nantucket',
#  'vardo',
#  'vyazemskiy',
#  'kang',
#  'yarim',
#  'ozgon',
#  'mareeba',
#  'grand river south east',
#  'lanzhou',
#  'jucurutu',
#  'capinota',
#  'grootfontein',
#  'atchison',
#  'voronezh',
#  'sao filipe',
#  'nizhniy tsasuchey',
#  'ahipara',
#  'poum',
#  'bridlington',
#  'gander',
#  'portland',
#  'kenai',
#  'hihifo',
#  'tezu',
#  'katobu',
#  'vuktyl',
#  'sarakhs',
#  'saint-francois',
#  'juneau',
#  'bekesszentandras',
#  'jardim',
#  'luena',
#  'zhangye',
#  'timra',
#  'nokha',
#  'ranong',
#  'sao domingos',
#  'koszalin',
#  'troitsko-pechorsk',
#  'diplo',
#  'varhaug',
#  'saint-pierre',
#  'ampere',
#  'aklavik',
#  'ranfurly',
#  'port moresby',
#  'pierre',
#  'morehead',
#  'faya',
#  'lucea',
#  'jevargi',
#  'anadyr',
#  'payo',
#  'sobolevo',
#  'nyurba',
#  'broken hill',
#  'fier',
#  'walla walla',
#  'trairi',
#  'ukiah',
#  'laives',
#  'omboue',
#  'marzuq',
#  'grindavik',
#  'fort nelson',
#  'ngukurr',
#  'lahat',
#  'karasburg',
#  'columbus',
#  'malwan',
#  'cikupa',
#  'saint-georges',
#  'namatanai',
#  'bombay',
#  'margate',
#  'gonen',
#  'pilao arcado',
#  'narimanov',
#  'khash',
#  'fereydunshahr',
#  'kaohsiung',
#  'doctor pedro p. pena',
#  'camacha',
#  'coihaique',
#  'pirenopolis',
#  'nangomba',
#  'nizhneyansk',
#  'quatre cocos',
#  'yining',
#  'pangnirtung',
#  'kotido',
#  'port augusta',
#  'marawi',
#  'bonthe',
#  'viransehir',
#  'xghajra',
#  'carupano',
#  'puerto escondido',
#  'odlabari',
#  'dahanu',
#  'wahran',
#  'algemesi',
#  'mentok',
#  'ambalavao',
#  'tautira',
#  'anage',
#  'hofn',
#  'felidhoo',
#  'altotting',
#  'opuwo',
#  'severomorsk',
#  'palmer',
#  'lengshuitan',
#  'flagstaff',
#  'itarema',
#  'tabiauea',
#  'phalodi',
#  'shieli',
#  'chimoio',
#  'broken arrow',
#  'frutal',
#  'jalu',
#  'kokkola',
#  'marienburg',
#  'haines junction',
#  'pangkalanbuun',
#  'saran',
#  'nyrob',
#  'charters towers',
#  'pandaria',
#  'praya',
#  'beira',
#  'coquimbo',
#  'kruisfontein',
#  'artyk',
#  'amudat',
#  'sao borja',
#  'dongsheng',
#  'laki',
#  'rungata',
#  'nikolsk',
#  'nabire',
#  'toshkivka',
#  'antalaha',
#  'ambilobe',
#  'dabola',
#  'cumaribo',
#  'el estor',
#  'karakendzha',
#  'manzil salim',
#  'matara',
#  'zlobin',
#  'kamenskiy',
#  'tomatlan',
#  'lohne',
#  'umm kaddadah',
#  'manakara',
#  'mecca',
#  'synya',
#  'homer',
#  'louiseville',
#  'guider',
#  'ariquemes',
#  'kangaba',
#  'lokoja',
#  'riyadh',
#  'ransang',
#  'burgeo',
#  'kassala',
#  'saravan',
#  'porto novo',
#  'gao',
#  'victor harbor',
#  'porto empedocle',
#  'nguiu',
#  'senador guiomard',
#  'tayu',
#  'coyah',
#  'san rafael',
#  'taltal',
#  'jega',
#  'afzalgarh',
#  'lichinga',
#  'iskateley',
#  'ust-kuyga',
#  'tokzar',
#  'sao felipe',
#  'ornskoldsvik',
#  'manokwari',
#  'mongoumba',
#  'akcakoca',
#  'diebougou',
#  'colwyn bay',
#  'ugra',
#  'noshiro',
#  'bantou',
#  'zhigansk',
#  'lusambo',
#  'santa vitoria do palmar',
#  'kananga',
#  'constantine',
#  'ondjiva',
#  'hami',
#  'pueblo nuevo',
#  'san severo',
#  'kysyl-syr',
#  'baturaja',
#  'foix',
#  'luzino',
#  'pemangkat',
#  'biltine']

# %%
# Get weather data
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + OpenWeather_API_KEY
#url = "http://api.openweathermap.org/data/2.5/weather?"
#url = f"{url}appid={OpenWeather_API_KEY}"
#units = "metric"
#url

# %%
# Create an empty list to hold the weather data.
city_data = []
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #print(city_weather)
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        #print(city_weather)
        #break
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | buala
# Processing Record 4 of Set 1 | kedrovyy
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | nakamura
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | pishva
# Processing Record 14 of Set 1 | waingapu
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | skibbereen
# Processing Record 17 of Set 1 | pimentel
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | miraflores
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | puerto del rosario
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | kerman
# Processing Record 27 of Set 1 | mbacke
# City not found. Skipping...
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | lavrentiya
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | galle
# Processing Record 33 of Set 1 | bentiu
# Processing Record 34 of Set 1 | metro
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | pandan
# Processing Record 38 of Set 1 | heyang
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | yelabuga
# Processing Record 42 of Set 1 | emborion
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 1 | esperance
# Processing Record 48 of Set 1 | atasu
# Processing Record 49 of Set 1 | sola
# Processing Record 50 of Set 1 | takoradi
# Processing Record 1 of Set 2 | weligama
# Processing Record 2 of Set 2 | pampierstad
# Processing Record 3 of Set 2 | kindersley
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | inhambane
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | puerto cortes
# City not found. Skipping...
# Processing Record 8 of Set 2 | brae
# Processing Record 9 of Set 2 | te anau
# Processing Record 10 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 2 | kungurtug
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | katangli
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | beringovskiy
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | lazaro cardenas
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | killarney
# Processing Record 21 of Set 2 | pokanayevka
# City not found. Skipping...
# Processing Record 22 of Set 2 | elliot lake
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | matsubase
# Processing Record 25 of Set 2 | touros
# Processing Record 26 of Set 2 | tome
# Processing Record 27 of Set 2 | pacific grove
# Processing Record 28 of Set 2 | ixtapa
# Processing Record 29 of Set 2 | hithadhoo
# Processing Record 30 of Set 2 | the pas
# Processing Record 31 of Set 2 | odesskoye
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | dingle
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | alexandria
# Processing Record 36 of Set 2 | chapadinha
# Processing Record 37 of Set 2 | biak
# Processing Record 38 of Set 2 | bubaque
# Processing Record 39 of Set 2 | yuxia
# Processing Record 40 of Set 2 | olinda
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 2 | puerto leguizamo
# Processing Record 44 of Set 2 | prince rupert
# Processing Record 45 of Set 2 | burica
# City not found. Skipping...
# Processing Record 46 of Set 2 | kirakira
# Processing Record 47 of Set 2 | mahibadhoo
# Processing Record 48 of Set 2 | sao felix do xingu
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | cap malheureux
# Processing Record 1 of Set 3 | tiznit
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | kurmanayevka
# Processing Record 5 of Set 3 | vanimo
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | mason city
# Processing Record 9 of Set 3 | neepawa
# Processing Record 10 of Set 3 | hinganghat
# Processing Record 11 of Set 3 | berlevag
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | leningradskiy
# Processing Record 14 of Set 3 | emba
# Processing Record 15 of Set 3 | severo-kurilsk
# Processing Record 16 of Set 3 | ayan
# Processing Record 17 of Set 3 | timaru
# Processing Record 18 of Set 3 | pinawa
# Processing Record 19 of Set 3 | shingu
# Processing Record 20 of Set 3 | alice springs
# Processing Record 21 of Set 3 | gua musang
# Processing Record 22 of Set 3 | tairua
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | seoul
# Processing Record 25 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | khani
# Processing Record 29 of Set 3 | maniitsoq
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | sungaipenuh
# Processing Record 32 of Set 3 | beipiao
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | sambek
# Processing Record 35 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 3 | umea
# Processing Record 37 of Set 3 | reftinskiy
# Processing Record 38 of Set 3 | kaitangata
# Processing Record 39 of Set 3 | marsh harbour
# Processing Record 40 of Set 3 | banjar
# Processing Record 41 of Set 3 | micheldorf
# Processing Record 42 of Set 3 | forchheim
# Processing Record 43 of Set 3 | kawambwa
# Processing Record 44 of Set 3 | boffa
# Processing Record 45 of Set 3 | carballo
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | grand-lahou
# Processing Record 48 of Set 3 | bayangol
# Processing Record 49 of Set 3 | hatfield
# Processing Record 50 of Set 3 | bumbuna
# Processing Record 1 of Set 4 | mahasamund
# Processing Record 2 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 4 | awjilah
# Processing Record 5 of Set 4 | sortavala
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | morant bay
# Processing Record 9 of Set 4 | georgiyevka
# Processing Record 10 of Set 4 | port-gentil
# Processing Record 11 of Set 4 | puerto ayora
# Processing Record 12 of Set 4 | alta floresta
# Processing Record 13 of Set 4 | macapa
# Processing Record 14 of Set 4 | hobart
# Processing Record 15 of Set 4 | huacho
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | hasaki
# Processing Record 18 of Set 4 | port hardy
# Processing Record 19 of Set 4 | guerrero negro
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | atherton
# Processing Record 22 of Set 4 | shimoda
# Processing Record 23 of Set 4 | ballina
# Processing Record 24 of Set 4 | port elizabeth
# Processing Record 25 of Set 4 | yulara
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | upernavik
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | elbistan
# Processing Record 30 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | libreville
# Processing Record 33 of Set 4 | vestmannaeyjar
# Processing Record 34 of Set 4 | misratah
# Processing Record 35 of Set 4 | port macquarie
# Processing Record 36 of Set 4 | bosaso
# Processing Record 37 of Set 4 | zhangzhou
# Processing Record 38 of Set 4 | palauig
# Processing Record 39 of Set 4 | parbhani
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | ucluelet
# Processing Record 42 of Set 4 | new amsterdam
# Processing Record 43 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | buraydah
# Processing Record 46 of Set 4 | mana
# Processing Record 47 of Set 4 | himora
# City not found. Skipping...
# Processing Record 48 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 4 | new norfolk
# Processing Record 50 of Set 4 | ribeira grande
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | san joaquin
# Processing Record 3 of Set 5 | kotel
# Processing Record 4 of Set 5 | amahai
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | kapiri mposhi
# Processing Record 8 of Set 5 | kolpashevo
# Processing Record 9 of Set 5 | nome
# Processing Record 10 of Set 5 | nouadhibou
# Processing Record 11 of Set 5 | atambua
# Processing Record 12 of Set 5 | qasigiannguit
# Processing Record 13 of Set 5 | astana
# Processing Record 14 of Set 5 | oistins
# Processing Record 15 of Set 5 | kamenka
# Processing Record 16 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | la paz
# Processing Record 19 of Set 5 | sibolga
# Processing Record 20 of Set 5 | merauke
# Processing Record 21 of Set 5 | kutum
# Processing Record 22 of Set 5 | kondinskoye
# Processing Record 23 of Set 5 | palora
# Processing Record 24 of Set 5 | macia
# Processing Record 25 of Set 5 | constitucion
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | kropotkin
# Processing Record 28 of Set 5 | vondrozo
# Processing Record 29 of Set 5 | malumfashi
# Processing Record 30 of Set 5 | gold coast
# Processing Record 31 of Set 5 | saint-joseph
# Processing Record 32 of Set 5 | east london
# Processing Record 33 of Set 5 | kholodnyy
# Processing Record 34 of Set 5 | osakarovka
# Processing Record 35 of Set 5 | madang
# Processing Record 36 of Set 5 | shelburne
# Processing Record 37 of Set 5 | vostok
# Processing Record 38 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 5 | oranjemund
# Processing Record 40 of Set 5 | necochea
# Processing Record 41 of Set 5 | altamira
# Processing Record 42 of Set 5 | richards bay
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | flinders
# Processing Record 45 of Set 5 | port blair
# Processing Record 46 of Set 5 | dahuk
# Processing Record 47 of Set 5 | kadhan
# Processing Record 48 of Set 5 | owo
# Processing Record 49 of Set 5 | wakkanai
# Processing Record 50 of Set 5 | saldanha
# Processing Record 1 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 6 | korla
# Processing Record 3 of Set 6 | newcastle
# Processing Record 4 of Set 6 | noumea
# Processing Record 5 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 6 | vozhega
# Processing Record 7 of Set 6 | rakhya
# City not found. Skipping...
# Processing Record 8 of Set 6 | ahuimanu
# Processing Record 9 of Set 6 | auki
# Processing Record 10 of Set 6 | ulladulla
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | pangai
# Processing Record 13 of Set 6 | mount isa
# Processing Record 14 of Set 6 | yuzhno-kurilsk
# Processing Record 15 of Set 6 | chyhyryn
# Processing Record 16 of Set 6 | nanortalik
# Processing Record 17 of Set 6 | ulaanbaatar
# Processing Record 18 of Set 6 | saint-philippe
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | victoria
# Processing Record 21 of Set 6 | mezen
# Processing Record 22 of Set 6 | yar-sale
# Processing Record 23 of Set 6 | carnarvon
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | huilong
# Processing Record 26 of Set 6 | maniago
# Processing Record 27 of Set 6 | sorland
# Processing Record 28 of Set 6 | fershampenuaz
# Processing Record 29 of Set 6 | iraucuba
# Processing Record 30 of Set 6 | krasnoshchekovo
# Processing Record 31 of Set 6 | narsaq
# Processing Record 32 of Set 6 | obigarm
# Processing Record 33 of Set 6 | rundu
# Processing Record 34 of Set 6 | asau
# Processing Record 35 of Set 6 | hambantota
# Processing Record 36 of Set 6 | weihe
# Processing Record 37 of Set 6 | morondava
# Processing Record 38 of Set 6 | menongue
# Processing Record 39 of Set 6 | safford
# Processing Record 40 of Set 6 | betamcherla
# Processing Record 41 of Set 6 | cabo san lucas
# Processing Record 42 of Set 6 | macamic
# Processing Record 43 of Set 6 | nemuro
# Processing Record 44 of Set 6 | dikson
# Processing Record 45 of Set 6 | yakeshi
# Processing Record 46 of Set 6 | padang
# Processing Record 47 of Set 6 | kokopo
# Processing Record 48 of Set 6 | christchurch
# Processing Record 49 of Set 6 | port lincoln
# Processing Record 50 of Set 6 | altagracia de orituco
# Processing Record 1 of Set 7 | ternate
# Processing Record 2 of Set 7 | meulaboh
# Processing Record 3 of Set 7 | felipe carrillo puerto
# Processing Record 4 of Set 7 | kiunga
# Processing Record 5 of Set 7 | lyubech
# Processing Record 6 of Set 7 | barranca
# Processing Record 7 of Set 7 | ostrovnoy
# Processing Record 8 of Set 7 | acarau
# Processing Record 9 of Set 7 | hirara
# Processing Record 10 of Set 7 | gazojak
# Processing Record 11 of Set 7 | valdivia
# Processing Record 12 of Set 7 | santa isabel do rio negro
# Processing Record 13 of Set 7 | naantali
# Processing Record 14 of Set 7 | manono
# Processing Record 15 of Set 7 | black river
# Processing Record 16 of Set 7 | shenjiamen
# Processing Record 17 of Set 7 | glenwood springs
# Processing Record 18 of Set 7 | codrington
# Processing Record 19 of Set 7 | polunochnoye
# Processing Record 20 of Set 7 | siderno
# Processing Record 21 of Set 7 | iqaluit
# Processing Record 22 of Set 7 | katima mulilo
# Processing Record 23 of Set 7 | gidam
# Processing Record 24 of Set 7 | yabelo
# Processing Record 25 of Set 7 | atbasar
# Processing Record 26 of Set 7 | north bend
# Processing Record 27 of Set 7 | sechura
# Processing Record 28 of Set 7 | kahului
# Processing Record 29 of Set 7 | waipawa
# Processing Record 30 of Set 7 | ketchikan
# Processing Record 31 of Set 7 | le port
# Processing Record 32 of Set 7 | goderich
# Processing Record 33 of Set 7 | riviere-au-renard
# Processing Record 34 of Set 7 | sept-iles
# Processing Record 35 of Set 7 | bontang
# Processing Record 36 of Set 7 | cortez
# Processing Record 37 of Set 7 | winneba
# Processing Record 38 of Set 7 | college
# Processing Record 39 of Set 7 | aykhal
# Processing Record 40 of Set 7 | bogatic
# Processing Record 41 of Set 7 | drumnadrochit
# Processing Record 42 of Set 7 | san felipe
# Processing Record 43 of Set 7 | sydney
# Processing Record 44 of Set 7 | kavieng
# Processing Record 45 of Set 7 | gamba
# Processing Record 46 of Set 7 | ajdabiya
# Processing Record 47 of Set 7 | namibe
# Processing Record 48 of Set 7 | sinnamary
# Processing Record 49 of Set 7 | gurlan
# Processing Record 50 of Set 7 | daru
# Processing Record 1 of Set 8 | gamboma
# Processing Record 2 of Set 8 | bafra
# Processing Record 3 of Set 8 | zemio
# Processing Record 4 of Set 8 | saint anthony
# Processing Record 5 of Set 8 | keetmanshoop
# Processing Record 6 of Set 8 | bury saint edmunds
# City not found. Skipping...
# Processing Record 7 of Set 8 | otta
# Processing Record 8 of Set 8 | isangel
# Processing Record 9 of Set 8 | marrakesh
# Processing Record 10 of Set 8 | dossor
# Processing Record 11 of Set 8 | harper
# Processing Record 12 of Set 8 | seymchan
# Processing Record 13 of Set 8 | kitimat
# Processing Record 14 of Set 8 | olafsvik
# Processing Record 15 of Set 8 | aykino
# Processing Record 16 of Set 8 | klaksvik
# Processing Record 17 of Set 8 | salou
# Processing Record 18 of Set 8 | bengkulu
# Processing Record 19 of Set 8 | agen
# Processing Record 20 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 8 | jumla
# Processing Record 22 of Set 8 | sayyan
# Processing Record 23 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 24 of Set 8 | ngaoundere
# Processing Record 25 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 8 | cidreira
# Processing Record 27 of Set 8 | ormara
# Processing Record 28 of Set 8 | spencer
# Processing Record 29 of Set 8 | juli
# Processing Record 30 of Set 8 | dakar
# Processing Record 31 of Set 8 | west wendover
# Processing Record 32 of Set 8 | kaniama
# Processing Record 33 of Set 8 | presidencia roque saenz pena
# Processing Record 34 of Set 8 | kojnare
# Processing Record 35 of Set 8 | beyneu
# Processing Record 36 of Set 8 | at-bashi
# Processing Record 37 of Set 8 | mandera
# Processing Record 38 of Set 8 | baculin
# Processing Record 39 of Set 8 | kresttsy
# Processing Record 40 of Set 8 | hobyo
# Processing Record 41 of Set 8 | peace river
# Processing Record 42 of Set 8 | pitimbu
# Processing Record 43 of Set 8 | san fernando
# Processing Record 44 of Set 8 | yugorsk
# Processing Record 45 of Set 8 | luancheng
# Processing Record 46 of Set 8 | beloha
# Processing Record 47 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 48 of Set 8 | okazaki
# Processing Record 49 of Set 8 | akureyri
# Processing Record 50 of Set 8 | banda aceh
# Processing Record 1 of Set 9 | hellvik
# Processing Record 2 of Set 9 | ous
# Processing Record 3 of Set 9 | condega
# Processing Record 4 of Set 9 | broome
# Processing Record 5 of Set 9 | lima
# Processing Record 6 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 9 | palembang
# Processing Record 8 of Set 9 | sabang
# Processing Record 9 of Set 9 | tuy hoa
# Processing Record 10 of Set 9 | goundam
# Processing Record 11 of Set 9 | xining
# Processing Record 12 of Set 9 | makat
# Processing Record 13 of Set 9 | hisar
# Processing Record 14 of Set 9 | vila franca do campo
# Processing Record 15 of Set 9 | atar
# Processing Record 16 of Set 9 | avera
# Processing Record 17 of Set 9 | dwarka
# Processing Record 18 of Set 9 | nishihara
# Processing Record 19 of Set 9 | shu
# Processing Record 20 of Set 9 | castricum
# Processing Record 21 of Set 9 | bilibino
# Processing Record 22 of Set 9 | tarpon springs
# Processing Record 23 of Set 9 | walvis bay
# Processing Record 24 of Set 9 | tateyama
# Processing Record 25 of Set 9 | sumbe
# Processing Record 26 of Set 9 | borogontsy
# Processing Record 27 of Set 9 | tancanhuitz
# Processing Record 28 of Set 9 | kayasula
# Processing Record 29 of Set 9 | lata
# Processing Record 30 of Set 9 | darhan
# Processing Record 31 of Set 9 | kununurra
# Processing Record 32 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 9 | taos
# Processing Record 34 of Set 9 | alofi
# Processing Record 35 of Set 9 | salme
# Processing Record 36 of Set 9 | evensk
# Processing Record 37 of Set 9 | pisco
# Processing Record 38 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 41 of Set 9 | dauphin
# Processing Record 42 of Set 9 | san quintin
# Processing Record 43 of Set 9 | iznik
# Processing Record 44 of Set 9 | townsville
# Processing Record 45 of Set 9 | tura
# Processing Record 46 of Set 9 | berezovka
# Processing Record 47 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 48 of Set 9 | sigli
# Processing Record 49 of Set 9 | alappuzha
# Processing Record 50 of Set 9 | fortuna
# Processing Record 1 of Set 10 | aloleng
# Processing Record 2 of Set 10 | luwuk
# Processing Record 3 of Set 10 | nova granada
# Processing Record 4 of Set 10 | muros
# Processing Record 5 of Set 10 | valparaiso
# Processing Record 6 of Set 10 | gizo
# Processing Record 7 of Set 10 | taklisah
# Processing Record 8 of Set 10 | umm lajj
# Processing Record 9 of Set 10 | mata
# Processing Record 10 of Set 10 | saint-augustin
# Processing Record 11 of Set 10 | libertador general san martin
# Processing Record 12 of Set 10 | villa carlos paz
# Processing Record 13 of Set 10 | shemgang
# Processing Record 14 of Set 10 | gat
# Processing Record 15 of Set 10 | rawson
# Processing Record 16 of Set 10 | mnogovershinnyy
# Processing Record 17 of Set 10 | kendari
# Processing Record 18 of Set 10 | husavik
# Processing Record 19 of Set 10 | ust-maya
# Processing Record 20 of Set 10 | hay river
# Processing Record 21 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 22 of Set 10 | chara
# Processing Record 23 of Set 10 | hun
# Processing Record 24 of Set 10 | aitape
# Processing Record 25 of Set 10 | yaval
# Processing Record 26 of Set 10 | dubasari
# Processing Record 27 of Set 10 | japura
# Processing Record 28 of Set 10 | svetlyy
# Processing Record 29 of Set 10 | makakilo city
# Processing Record 30 of Set 10 | flin flon
# Processing Record 31 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 10 | la ronge
# Processing Record 33 of Set 10 | vila velha
# Processing Record 34 of Set 10 | tecoanapa
# Processing Record 35 of Set 10 | oksfjord
# Processing Record 36 of Set 10 | lompoc
# Processing Record 37 of Set 10 | mount gambier
# Processing Record 38 of Set 10 | huarmey
# Processing Record 39 of Set 10 | birnin kebbi
# Processing Record 40 of Set 10 | corinto
# Processing Record 41 of Set 10 | fairbanks
# Processing Record 42 of Set 10 | kabanjahe
# Processing Record 43 of Set 10 | athabasca
# Processing Record 44 of Set 10 | yarada
# Processing Record 45 of Set 10 | cabra
# Processing Record 46 of Set 10 | macheng
# Processing Record 47 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 10 | suwalki
# Processing Record 49 of Set 10 | lagoa
# Processing Record 50 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 1 of Set 11 | kantang
# Processing Record 2 of Set 11 | ozernovskiy
# Processing Record 3 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 4 of Set 11 | erzin
# Processing Record 5 of Set 11 | yumen
# Processing Record 6 of Set 11 | makungu
# Processing Record 7 of Set 11 | vao
# Processing Record 8 of Set 11 | la macarena
# Processing Record 9 of Set 11 | russell
# Processing Record 10 of Set 11 | grand gaube
# Processing Record 11 of Set 11 | barcelos
# Processing Record 12 of Set 11 | lorengau
# Processing Record 13 of Set 11 | nsanje
# Processing Record 14 of Set 11 | isla mujeres
# Processing Record 15 of Set 11 | jibuti
# Processing Record 16 of Set 11 | havre
# Processing Record 17 of Set 11 | okhotsk
# Processing Record 18 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 11 | kyshtovka
# Processing Record 20 of Set 11 | malartic
# Processing Record 21 of Set 11 | aripuana
# Processing Record 22 of Set 11 | shaikhpura
# Processing Record 23 of Set 11 | marang
# Processing Record 24 of Set 11 | fort wellington
# Processing Record 25 of Set 11 | quesnel
# Processing Record 26 of Set 11 | jacareacanga
# Processing Record 27 of Set 11 | lumut
# Processing Record 28 of Set 11 | muscat
# Processing Record 29 of Set 11 | ilhabela
# Processing Record 30 of Set 11 | bernalillo
# Processing Record 31 of Set 11 | hanna
# Processing Record 32 of Set 11 | furukawa
# Processing Record 33 of Set 11 | lenti
# Processing Record 34 of Set 11 | sarmanovo
# Processing Record 35 of Set 11 | comodoro rivadavia
# Processing Record 36 of Set 11 | ozerki
# Processing Record 37 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 11 | tessalit
# Processing Record 39 of Set 11 | sioux lookout
# Processing Record 40 of Set 11 | lasa
# Processing Record 41 of Set 11 | staryy nadym
# Processing Record 42 of Set 11 | ilulissat
# Processing Record 43 of Set 11 | nantucket
# Processing Record 44 of Set 11 | vardo
# Processing Record 45 of Set 11 | vyazemskiy
# Processing Record 46 of Set 11 | kang
# Processing Record 47 of Set 11 | yarim
# Processing Record 48 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 11 | mareeba
# Processing Record 50 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 12 | lanzhou
# Processing Record 2 of Set 12 | jucurutu
# Processing Record 3 of Set 12 | capinota
# Processing Record 4 of Set 12 | grootfontein
# Processing Record 5 of Set 12 | atchison
# Processing Record 6 of Set 12 | voronezh
# Processing Record 7 of Set 12 | sao filipe
# Processing Record 8 of Set 12 | nizhniy tsasuchey
# Processing Record 9 of Set 12 | ahipara
# Processing Record 10 of Set 12 | poum
# Processing Record 11 of Set 12 | bridlington
# Processing Record 12 of Set 12 | gander
# Processing Record 13 of Set 12 | portland
# Processing Record 14 of Set 12 | kenai
# Processing Record 15 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 12 | tezu
# Processing Record 17 of Set 12 | katobu
# Processing Record 18 of Set 12 | vuktyl
# Processing Record 19 of Set 12 | sarakhs
# Processing Record 20 of Set 12 | saint-francois
# Processing Record 21 of Set 12 | juneau
# Processing Record 22 of Set 12 | bekesszentandras
# Processing Record 23 of Set 12 | jardim
# Processing Record 24 of Set 12 | luena
# Processing Record 25 of Set 12 | zhangye
# Processing Record 26 of Set 12 | timra
# Processing Record 27 of Set 12 | nokha
# Processing Record 28 of Set 12 | ranong
# Processing Record 29 of Set 12 | sao domingos
# Processing Record 30 of Set 12 | koszalin
# Processing Record 31 of Set 12 | troitsko-pechorsk
# Processing Record 32 of Set 12 | diplo
# Processing Record 33 of Set 12 | varhaug
# Processing Record 34 of Set 12 | saint-pierre
# Processing Record 35 of Set 12 | ampere
# Processing Record 36 of Set 12 | aklavik
# Processing Record 37 of Set 12 | ranfurly
# Processing Record 38 of Set 12 | port moresby
# Processing Record 39 of Set 12 | pierre
# Processing Record 40 of Set 12 | morehead
# Processing Record 41 of Set 12 | faya
# Processing Record 42 of Set 12 | lucea
# Processing Record 43 of Set 12 | jevargi
# Processing Record 44 of Set 12 | anadyr
# Processing Record 45 of Set 12 | payo
# Processing Record 46 of Set 12 | sobolevo
# Processing Record 47 of Set 12 | nyurba
# Processing Record 48 of Set 12 | broken hill
# Processing Record 49 of Set 12 | fier
# Processing Record 50 of Set 12 | walla walla
# Processing Record 1 of Set 13 | trairi
# Processing Record 2 of Set 13 | ukiah
# Processing Record 3 of Set 13 | laives
# Processing Record 4 of Set 13 | omboue
# Processing Record 5 of Set 13 | marzuq
# Processing Record 6 of Set 13 | grindavik
# Processing Record 7 of Set 13 | fort nelson
# Processing Record 8 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 13 | lahat
# Processing Record 10 of Set 13 | karasburg
# Processing Record 11 of Set 13 | columbus
# Processing Record 12 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 13 | cikupa
# Processing Record 14 of Set 13 | saint-georges
# Processing Record 15 of Set 13 | namatanai
# Processing Record 16 of Set 13 | bombay
# Processing Record 17 of Set 13 | margate
# Processing Record 18 of Set 13 | gonen
# Processing Record 19 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 20 of Set 13 | narimanov
# Processing Record 21 of Set 13 | khash
# Processing Record 22 of Set 13 | fereydunshahr
# Processing Record 23 of Set 13 | kaohsiung
# Processing Record 24 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 13 | camacha
# Processing Record 26 of Set 13 | coihaique
# Processing Record 27 of Set 13 | pirenopolis
# Processing Record 28 of Set 13 | nangomba
# Processing Record 29 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 13 | quatre cocos
# Processing Record 31 of Set 13 | yining
# Processing Record 32 of Set 13 | pangnirtung
# Processing Record 33 of Set 13 | kotido
# Processing Record 34 of Set 13 | port augusta
# Processing Record 35 of Set 13 | marawi
# Processing Record 36 of Set 13 | bonthe
# Processing Record 37 of Set 13 | viransehir
# Processing Record 38 of Set 13 | xghajra
# City not found. Skipping...
# Processing Record 39 of Set 13 | carupano
# Processing Record 40 of Set 13 | puerto escondido
# Processing Record 41 of Set 13 | odlabari
# Processing Record 42 of Set 13 | dahanu
# Processing Record 43 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 13 | algemesi
# Processing Record 45 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 13 | ambalavao
# Processing Record 47 of Set 13 | tautira
# Processing Record 48 of Set 13 | anage
# Processing Record 49 of Set 13 | hofn
# Processing Record 50 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 1 of Set 14 | altotting
# Processing Record 2 of Set 14 | opuwo
# Processing Record 3 of Set 14 | severomorsk
# Processing Record 4 of Set 14 | palmer
# Processing Record 5 of Set 14 | lengshuitan
# Processing Record 6 of Set 14 | flagstaff
# Processing Record 7 of Set 14 | itarema
# Processing Record 8 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 14 | phalodi
# Processing Record 10 of Set 14 | shieli
# Processing Record 11 of Set 14 | chimoio
# Processing Record 12 of Set 14 | broken arrow
# Processing Record 13 of Set 14 | frutal
# Processing Record 14 of Set 14 | jalu
# Processing Record 15 of Set 14 | kokkola
# Processing Record 16 of Set 14 | marienburg
# Processing Record 17 of Set 14 | haines junction
# Processing Record 18 of Set 14 | pangkalanbuun
# Processing Record 19 of Set 14 | saran
# Processing Record 20 of Set 14 | nyrob
# Processing Record 21 of Set 14 | charters towers
# Processing Record 22 of Set 14 | pandaria
# Processing Record 23 of Set 14 | praya
# Processing Record 24 of Set 14 | beira
# Processing Record 25 of Set 14 | coquimbo
# Processing Record 26 of Set 14 | kruisfontein
# Processing Record 27 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 14 | amudat
# Processing Record 29 of Set 14 | sao borja
# Processing Record 30 of Set 14 | dongsheng
# Processing Record 31 of Set 14 | laki
# Processing Record 32 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 14 | nikolsk
# Processing Record 34 of Set 14 | nabire
# Processing Record 35 of Set 14 | toshkivka
# Processing Record 36 of Set 14 | antalaha
# Processing Record 37 of Set 14 | ambilobe
# Processing Record 38 of Set 14 | dabola
# Processing Record 39 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 14 | el estor
# Processing Record 41 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 42 of Set 14 | manzil salim
# Processing Record 43 of Set 14 | matara
# Processing Record 44 of Set 14 | zlobin
# Processing Record 45 of Set 14 | kamenskiy
# Processing Record 46 of Set 14 | tomatlan
# Processing Record 47 of Set 14 | lohne
# Processing Record 48 of Set 14 | umm kaddadah
# Processing Record 49 of Set 14 | manakara
# Processing Record 50 of Set 14 | mecca
# Processing Record 1 of Set 15 | synya
# Processing Record 2 of Set 15 | homer
# Processing Record 3 of Set 15 | louiseville
# Processing Record 4 of Set 15 | guider
# Processing Record 5 of Set 15 | ariquemes
# Processing Record 6 of Set 15 | kangaba
# Processing Record 7 of Set 15 | lokoja
# Processing Record 8 of Set 15 | riyadh
# Processing Record 9 of Set 15 | ransang
# Processing Record 10 of Set 15 | burgeo
# Processing Record 11 of Set 15 | kassala
# Processing Record 12 of Set 15 | saravan
# Processing Record 13 of Set 15 | porto novo
# Processing Record 14 of Set 15 | gao
# Processing Record 15 of Set 15 | victor harbor
# Processing Record 16 of Set 15 | porto empedocle
# Processing Record 17 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 15 | senador guiomard
# Processing Record 19 of Set 15 | tayu
# Processing Record 20 of Set 15 | coyah
# Processing Record 21 of Set 15 | san rafael
# Processing Record 22 of Set 15 | taltal
# Processing Record 23 of Set 15 | jega
# Processing Record 24 of Set 15 | afzalgarh
# Processing Record 25 of Set 15 | lichinga
# Processing Record 26 of Set 15 | iskateley
# Processing Record 27 of Set 15 | ust-kuyga
# Processing Record 28 of Set 15 | tokzar
# City not found. Skipping...
# Processing Record 29 of Set 15 | sao felipe
# Processing Record 30 of Set 15 | ornskoldsvik
# Processing Record 31 of Set 15 | manokwari
# Processing Record 32 of Set 15 | mongoumba
# Processing Record 33 of Set 15 | akcakoca
# Processing Record 34 of Set 15 | diebougou
# Processing Record 35 of Set 15 | colwyn bay
# Processing Record 36 of Set 15 | ugra
# Processing Record 37 of Set 15 | noshiro
# Processing Record 38 of Set 15 | bantou
# Processing Record 39 of Set 15 | zhigansk
# Processing Record 40 of Set 15 | lusambo
# Processing Record 41 of Set 15 | santa vitoria do palmar
# Processing Record 42 of Set 15 | kananga
# Processing Record 43 of Set 15 | constantine
# Processing Record 44 of Set 15 | ondjiva
# Processing Record 45 of Set 15 | hami
# Processing Record 46 of Set 15 | pueblo nuevo
# Processing Record 47 of Set 15 | san severo
# Processing Record 48 of Set 15 | kysyl-syr
# Processing Record 49 of Set 15 | baturaja
# Processing Record 50 of Set 15 | foix
# Processing Record 1 of Set 16 | luzino
# Processing Record 2 of Set 16 | pemangkat
# Processing Record 3 of Set 16 | biltine

# %%
city_data
# Out:
# [{'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 58.03,
#   'Humidity': 76,
#   'Cloudiness': 71,
#   'Wind Speed': 19.62,
#   'Current Description': 'broken clouds'},
#  {'City': 'Buala',
#   'Country': 'SB',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 79.7,
#   'Humidity': 82,
#   'Cloudiness': 5,
#   'Wind Speed': 8.77,
#   'Current Description': 'clear sky'},
#  {'City': 'Kedrovyy',
#   'Country': 'RU',
#   'Lat': 56.1667,
#   'Lng': 91.8167,
#   'Max Temp': 68.41,
#   'Humidity': 97,
#   'Cloudiness': 42,
#   'Wind Speed': 4.47,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 70.21,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 6.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 45.52,
#   'Humidity': 57,
#   'Cloudiness': 10,
#   'Wind Speed': 3.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 83.26,
#   'Humidity': 52,
#   'Cloudiness': 61,
#   'Wind Speed': 1.16,
#   'Current Description': 'broken clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 75.79,
#   'Humidity': 80,
#   'Cloudiness': 26,
#   'Wind Speed': 12.28,
#   'Current Description': 'light rain'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.46,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nakamura',
#   'Country': 'JP',
#   'Lat': 32.9833,
#   'Lng': 132.9333,
#   'Max Temp': 77.29,
#   'Humidity': 97,
#   'Cloudiness': 96,
#   'Wind Speed': 3.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 44.71,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pishva',
#   'Country': 'IR',
#   'Lat': 35.308,
#   'Lng': 51.7267,
#   'Max Temp': 93.78,
#   'Humidity': 19,
#   'Cloudiness': 57,
#   'Wind Speed': 6.17,
#   'Current Description': 'broken clouds'},
#  {'City': 'Waingapu',
#   'Country': 'ID',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 73.44,
#   'Humidity': 88,
#   'Cloudiness': 19,
#   'Wind Speed': 6.31,
#   'Current Description': 'few clouds'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 54.01,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Skibbereen',
#   'Country': 'IE',
#   'Lat': 51.55,
#   'Lng': -9.2667,
#   'Max Temp': 63.1,
#   'Humidity': 66,
#   'Cloudiness': 72,
#   'Wind Speed': 14.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pimentel',
#   'Country': 'PE',
#   'Lat': -6.8367,
#   'Lng': -79.9342,
#   'Max Temp': 70.09,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 57.92,
#   'Humidity': 68,
#   'Cloudiness': 76,
#   'Wind Speed': 5.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.36,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Miraflores',
#   'Country': 'MX',
#   'Lat': 19.2167,
#   'Lng': -98.8083,
#   'Max Temp': 68.04,
#   'Humidity': 71,
#   'Cloudiness': 66,
#   'Wind Speed': 2.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 33.44,
#   'Humidity': 97,
#   'Cloudiness': 43,
#   'Wind Speed': 3.2,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 60.82,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 8.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Del Rosario',
#   'Country': 'ES',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp': 76.75,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Current Description': 'few clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 71.87,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 17.74,
#   'Current Description': 'light rain'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 57.25,
#   'Humidity': 92,
#   'Cloudiness': 92,
#   'Wind Speed': 3.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kerman',
#   'Country': 'IR',
#   'Lat': 30.2832,
#   'Lng': 57.0788,
#   'Max Temp': 76.86,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 61.32,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 42.62,
#   'Humidity': 86,
#   'Cloudiness': 45,
#   'Wind Speed': 3.31,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 88.63,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 57.96,
#   'Humidity': 61,
#   'Cloudiness': 80,
#   'Wind Speed': 3.13,
#   'Current Description': 'broken clouds'},
#  {'City': 'Galle',
#   'Country': 'LK',
#   'Lat': 6.0367,
#   'Lng': 80.217,
#   'Max Temp': 79,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 16.02,
#   'Current Description': 'moderate rain'},
#  {'City': 'Bentiu',
#   'Country': 'SS',
#   'Lat': 9.2333,
#   'Lng': 29.8333,
#   'Max Temp': 71.42,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Metro',
#   'Country': 'ID',
#   'Lat': -5.1131,
#   'Lng': 105.3067,
#   'Max Temp': 74.95,
#   'Humidity': 92,
#   'Cloudiness': 24,
#   'Wind Speed': 1.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 66.09,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 2.84,
#   'Current Description': 'broken clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 77.81,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 24.79,
#   'Current Description': 'light rain'},
#  {'City': 'Pandan',
#   'Country': 'PH',
#   'Lat': 14.0453,
#   'Lng': 124.1694,
#   'Max Temp': 80.13,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Heyang',
#   'Country': 'CN',
#   'Lat': 26.1011,
#   'Lng': 107.473,
#   'Max Temp': 67.95,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 1.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 54.27,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 73.36,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Yelabuga',
#   'Country': 'RU',
#   'Lat': 55.7613,
#   'Lng': 52.0649,
#   'Max Temp': 69.35,
#   'Humidity': 64,
#   'Cloudiness': 96,
#   'Wind Speed': 0.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Emborion',
#   'Country': 'GR',
#   'Lat': 40.4833,
#   'Lng': 21.55,
#   'Max Temp': 80.96,
#   'Humidity': 51,
#   'Cloudiness': 58,
#   'Wind Speed': 6.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 78.03,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 43.3,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 50.95,
#   'Humidity': 68,
#   'Cloudiness': 42,
#   'Wind Speed': 14.14,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Atasu',
#   'Country': 'KZ',
#   'Lat': 48.6814,
#   'Lng': 71.6433,
#   'Max Temp': 64.29,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 6.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 78.93,
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 15.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Takoradi',
#   'Country': 'GH',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 75.51,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 12.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Weligama',
#   'Country': 'LK',
#   'Lat': 5.9667,
#   'Lng': 80.4167,
#   'Max Temp': 78.17,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 13.94,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Pampierstad',
#   'Country': 'ZA',
#   'Lat': -27.7832,
#   'Lng': 24.6877,
#   'Max Temp': 52.72,
#   'Humidity': 31,
#   'Cloudiness': 5,
#   'Wind Speed': 7.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Kindersley',
#   'Country': 'CA',
#   'Lat': 51.4668,
#   'Lng': -109.1682,
#   'Max Temp': 73.42,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 43.92,
#   'Humidity': 79,
#   'Cloudiness': 29,
#   'Wind Speed': 15.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 66.18,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 51.8,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 54.27,
#   'Humidity': 70,
#   'Cloudiness': 26,
#   'Wind Speed': 11.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 31.33,
#   'Humidity': 91,
#   'Cloudiness': 49,
#   'Wind Speed': 1.43,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kungurtug',
#   'Country': 'RU',
#   'Lat': 50.5994,
#   'Lng': 97.5228,
#   'Max Temp': 54.27,
#   'Humidity': 86,
#   'Cloudiness': 83,
#   'Wind Speed': 2.84,
#   'Current Description': 'broken clouds'},
#  {'City': 'Katangli',
#   'Country': 'RU',
#   'Lat': 51.7102,
#   'Lng': 143.2326,
#   'Max Temp': 49.41,
#   'Humidity': 91,
#   'Cloudiness': 37,
#   'Wind Speed': 8.52,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 47.21,
#   'Humidity': 66,
#   'Cloudiness': 10,
#   'Wind Speed': 16.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 49.21,
#   'Humidity': 74,
#   'Cloudiness': 92,
#   'Wind Speed': 2.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 51.19,
#   'Humidity': 80,
#   'Cloudiness': 23,
#   'Wind Speed': 1.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 45.23,
#   'Humidity': 69,
#   'Cloudiness': 3,
#   'Wind Speed': 9.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Lazaro Cardenas',
#   'Country': 'MX',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 87.3,
#   'Humidity': 60,
#   'Cloudiness': 79,
#   'Wind Speed': 1.52,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 71.85,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Killarney',
#   'Country': 'IE',
#   'Lat': 52.05,
#   'Lng': -9.5167,
#   'Max Temp': 66.25,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Elliot Lake',
#   'Country': 'CA',
#   'Lat': 46.3834,
#   'Lng': -82.6331,
#   'Max Temp': 76.6,
#   'Humidity': 52,
#   'Cloudiness': 16,
#   'Wind Speed': 9.42,
#   'Current Description': 'few clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 44.62,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 14.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Matsubase',
#   'Country': 'JP',
#   'Lat': 32.65,
#   'Lng': 130.6667,
#   'Max Temp': 80.19,
#   'Humidity': 78,
#   'Cloudiness': 77,
#   'Wind Speed': 5.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 80.92,
#   'Humidity': 74,
#   'Cloudiness': 26,
#   'Wind Speed': 15.37,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tome',
#   'Country': 'CL',
#   'Lat': -36.6167,
#   'Lng': -72.95,
#   'Max Temp': 54.21,
#   'Humidity': 71,
#   'Cloudiness': 83,
#   'Wind Speed': 4.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 68.41,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 5.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 85.23,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 78.66,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 13.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'The Pas',
#   'Country': 'CA',
#   'Lat': 53.8251,
#   'Lng': -101.2541,
#   'Max Temp': 68.02,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Odesskoye',
#   'Country': 'RU',
#   'Lat': 54.2111,
#   'Lng': 72.9651,
#   'Max Temp': 67.57,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 8.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 46.8,
#   'Humidity': 65,
#   'Cloudiness': 6,
#   'Wind Speed': 3.98,
#   'Current Description': 'clear sky'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 76.33,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 66.36,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Alexandria',
#   'Country': 'EG',
#   'Lat': 31.2156,
#   'Lng': 29.9553,
#   'Max Temp': 81.14,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chapadinha',
#   'Country': 'BR',
#   'Lat': -3.7417,
#   'Lng': -43.3603,
#   'Max Temp': 90.52,
#   'Humidity': 49,
#   'Cloudiness': 55,
#   'Wind Speed': 2.95,
#   'Current Description': 'broken clouds'},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 75.56,
#   'Humidity': 86,
#   'Cloudiness': 96,
#   'Wind Speed': 2.55,
#   'Current Description': 'light rain'},
#  {'City': 'Bubaque',
#   'Country': 'GW',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 79.68,
#   'Humidity': 79,
#   'Cloudiness': 10,
#   'Wind Speed': 16.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Yuxia',
#   'Country': 'CN',
#   'Lat': 34.0615,
#   'Lng': 108.6291,
#   'Max Temp': 81.21,
#   'Humidity': 66,
#   'Cloudiness': 2,
#   'Wind Speed': 5.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Olinda',
#   'Country': 'BR',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 80.33,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 46.65,
#   'Humidity': 71,
#   'Cloudiness': 4,
#   'Wind Speed': 3.4,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Leguizamo',
#   'Country': 'CO',
#   'Lat': -0.1934,
#   'Lng': -74.7819,
#   'Max Temp': 90.32,
#   'Humidity': 50,
#   'Cloudiness': 60,
#   'Wind Speed': 0.89,
#   'Current Description': 'broken clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 59.09,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kirakira',
#   'Country': 'SB',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 78.15,
#   'Humidity': 86,
#   'Cloudiness': 25,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mahibadhoo',
#   'Country': 'MV',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 78.01,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 32.01,
#   'Current Description': 'light rain'},
#  {'City': 'Sao Felix Do Xingu',
#   'Country': 'BR',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 91.74,
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 0.78,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 38.35,
#   'Humidity': 87,
#   'Cloudiness': 63,
#   'Wind Speed': 6.31,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 71.47,
#   'Humidity': 69,
#   'Cloudiness': 12,
#   'Wind Speed': 7,
#   'Current Description': 'few clouds'},
#  {'City': 'Tiznit',
#   'Country': 'MA',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 88.66,
#   'Humidity': 33,
#   'Cloudiness': 7,
#   'Wind Speed': 4.81,
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.19,
#   'Humidity': 77,
#   'Cloudiness': 41,
#   'Wind Speed': 15.23,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 86.04,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Kurmanayevka',
#   'Country': 'RU',
#   'Lat': 52.5093,
#   'Lng': 52.0675,
#   'Max Temp': 69.42,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 78.22,
#   'Humidity': 87,
#   'Cloudiness': 47,
#   'Wind Speed': 5.53,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 76.87,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 37.63,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'fog'},
#  {'City': 'Mason City',
#   'Country': 'US',
#   'Lat': 43.1536,
#   'Lng': -93.201,
#   'Max Temp': 82.65,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Neepawa',
#   'Country': 'CA',
#   'Lat': 50.2289,
#   'Lng': -99.4664,
#   'Max Temp': 66.6,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hinganghat',
#   'Country': 'IN',
#   'Lat': 20.5667,
#   'Lng': 78.8333,
#   'Max Temp': 82.98,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 58.8,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 48.47,
#   'Humidity': 66,
#   'Cloudiness': 11,
#   'Wind Speed': 5.12,
#   'Current Description': 'few clouds'},
#  {'City': 'Emba',
#   'Country': 'KZ',
#   'Lat': 48.8264,
#   'Lng': 58.1442,
#   'Max Temp': 75.34,
#   'Humidity': 43,
#   'Cloudiness': 42,
#   'Wind Speed': 7.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 52.03,
#   'Humidity': 91,
#   'Cloudiness': 60,
#   'Wind Speed': 10.54,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ayan',
#   'Country': 'RU',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 56.8,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Timaru',
#   'Country': 'NZ',
#   'Lat': -44.4,
#   'Lng': 171.25,
#   'Max Temp': 37.08,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Pinawa',
#   'Country': 'CA',
#   'Lat': 50.1489,
#   'Lng': -95.8811,
#   'Max Temp': 65.16,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shingu',
#   'Country': 'JP',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 76.57,
#   'Humidity': 88,
#   'Cloudiness': 58,
#   'Wind Speed': 4.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 45.95,
#   'Humidity': 53,
#   'Cloudiness': 2,
#   'Wind Speed': 1.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Gua Musang',
#   'Country': 'MY',
#   'Lat': 4.8823,
#   'Lng': 101.9644,
#   'Max Temp': 73.96,
#   'Humidity': 98,
#   'Cloudiness': 94,
#   'Wind Speed': 1.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tairua',
#   'Country': 'NZ',
#   'Lat': -37.0167,
#   'Lng': 175.85,
#   'Max Temp': 49.51,
#   'Humidity': 81,
#   'Cloudiness': 3,
#   'Wind Speed': 9.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 43.81,
#   'Humidity': 69,
#   'Cloudiness': 35,
#   'Wind Speed': 6.46,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Seoul',
#   'Country': 'KR',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 78.4,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 84.13,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'light rain'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 56.32,
#   'Humidity': 55,
#   'Cloudiness': 45,
#   'Wind Speed': 12.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Khani',
#   'Country': 'GE',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 69.37,
#   'Humidity': 95,
#   'Cloudiness': 3,
#   'Wind Speed': 1.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 42.46,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 6.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 78.89,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sungaipenuh',
#   'Country': 'ID',
#   'Lat': -2.0833,
#   'Lng': 101.3833,
#   'Max Temp': 64.78,
#   'Humidity': 96,
#   'Cloudiness': 76,
#   'Wind Speed': 2.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Beipiao',
#   'Country': 'CN',
#   'Lat': 41.7919,
#   'Lng': 120.7792,
#   'Max Temp': 71.33,
#   'Humidity': 94,
#   'Cloudiness': 1,
#   'Wind Speed': 4.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 78.53,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sambek',
#   'Country': 'RU',
#   'Lat': 47.7431,
#   'Lng': 39.8308,
#   'Max Temp': 85.28,
#   'Humidity': 36,
#   'Cloudiness': 66,
#   'Wind Speed': 10.69,
#   'Current Description': 'broken clouds'},
#  {'City': 'Umea',
#   'Country': 'SE',
#   'Lat': 63.8284,
#   'Lng': 20.2597,
#   'Max Temp': 64.33,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Reftinskiy',
#   'Country': 'RU',
#   'Lat': 57.0901,
#   'Lng': 61.6769,
#   'Max Temp': 59.22,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 5.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 39.04,
#   'Humidity': 92,
#   'Cloudiness': 57,
#   'Wind Speed': 7.07,
#   'Current Description': 'broken clouds'},
#  {'City': 'Marsh Harbour',
#   'Country': 'BS',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 84.09,
#   'Humidity': 71,
#   'Cloudiness': 28,
#   'Wind Speed': 12.86,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Banjar',
#   'Country': 'ID',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 72.97,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 2.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Micheldorf',
#   'Country': 'AT',
#   'Lat': 46.9222,
#   'Lng': 14.4405,
#   'Max Temp': 76.8,
#   'Humidity': 71,
#   'Cloudiness': 31,
#   'Wind Speed': 4.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Forchheim',
#   'Country': 'DE',
#   'Lat': 49.7175,
#   'Lng': 11.0588,
#   'Max Temp': 81.39,
#   'Humidity': 57,
#   'Cloudiness': 90,
#   'Wind Speed': 3.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kawambwa',
#   'Country': 'ZM',
#   'Lat': -9.7915,
#   'Lng': 29.0791,
#   'Max Temp': 67.28,
#   'Humidity': 34,
#   'Cloudiness': 4,
#   'Wind Speed': 3.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Boffa',
#   'Country': 'GN',
#   'Lat': 10.1667,
#   'Lng': -14.0333,
#   'Max Temp': 80.51,
#   'Humidity': 77,
#   'Cloudiness': 62,
#   'Wind Speed': 8.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Carballo',
#   'Country': 'ES',
#   'Lat': 43.213,
#   'Lng': -8.691,
#   'Max Temp': 89.02,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 11.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Grand-Lahou',
#   'Country': 'CI',
#   'Lat': 5.1367,
#   'Lng': -5.0242,
#   'Max Temp': 75.99,
#   'Humidity': 82,
#   'Cloudiness': 94,
#   'Wind Speed': 11.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bayangol',
#   'Country': 'RU',
#   'Lat': 50.6977,
#   'Lng': 103.4656,
#   'Max Temp': 52.21,
#   'Humidity': 93,
#   'Cloudiness': 6,
#   'Wind Speed': 2.33,
#   'Current Description': 'clear sky'},
#  {'City': 'Hatfield',
#   'Country': 'GB',
#   'Lat': 51.7634,
#   'Lng': -0.2242,
#   'Max Temp': 79.88,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bumbuna',
#   'Country': 'SL',
#   'Lat': 9.05,
#   'Lng': -11.7333,
#   'Max Temp': 77.61,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 3.6,
#   'Current Description': 'light rain'},
#  {'City': 'Mahasamund',
#   'Country': 'IN',
#   'Lat': 21.1,
#   'Lng': 82.1,
#   'Max Temp': 82.67,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Awjilah',
#   'Country': 'LY',
#   'Lat': 29.1081,
#   'Lng': 21.2869,
#   'Max Temp': 91.6,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 18.45,
#   'Current Description': 'clear sky'},
#  {'City': 'Sortavala',
#   'Country': 'RU',
#   'Lat': 61.7053,
#   'Lng': 30.6918,
#   'Max Temp': 58.24,
#   'Humidity': 79,
#   'Cloudiness': 92,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 79.81,
#   'Humidity': 91,
#   'Cloudiness': 88,
#   'Wind Speed': 11.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 79.12,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Morant Bay',
#   'Country': 'JM',
#   'Lat': 17.8815,
#   'Lng': -76.4093,
#   'Max Temp': 94.71,
#   'Humidity': 70,
#   'Cloudiness': 4,
#   'Wind Speed': 16.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Georgiyevka',
#   'Country': 'KZ',
#   'Lat': 43.0369,
#   'Lng': 74.7114,
#   'Max Temp': 71.64,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 6.71,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 76.96,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 76.96,
#   'Humidity': 87,
#   'Cloudiness': 93,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alta Floresta',
#   'Country': 'BR',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 94.82,
#   'Humidity': 28,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Macapa',
#   'Country': 'BR',
#   'Lat': 0.0389,
#   'Lng': -51.0664,
#   'Max Temp': 91.38,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 49.86,
#   'Humidity': 78,
#   'Cloudiness': 92,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Huacho',
#   'Country': 'PE',
#   'Lat': -11.1067,
#   'Lng': -77.605,
#   'Max Temp': 66.43,
#   'Humidity': 70,
#   'Cloudiness': 43,
#   'Wind Speed': 10.38,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 81,
#   'Humidity': 85,
#   'Cloudiness': 89,
#   'Wind Speed': 7.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 60.98,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'fog'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 82.72,
#   'Humidity': 46,
#   'Cloudiness': 10,
#   'Wind Speed': 7.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 48.06,
#   'Humidity': 80,
#   'Cloudiness': 9,
#   'Wind Speed': 4.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Atherton',
#   'Country': 'GB',
#   'Lat': 53.5237,
#   'Lng': -2.4935,
#   'Max Temp': 67.89,
#   'Humidity': 58,
#   'Cloudiness': 3,
#   'Wind Speed': 8.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Shimoda',
#   'Country': 'JP',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 79.11,
#   'Humidity': 91,
#   'Cloudiness': 69,
#   'Wind Speed': 11.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ballina',
#   'Country': 'AU',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 58.01,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 6.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 53.89,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 48.24,
#   'Humidity': 41,
#   'Cloudiness': 2,
#   'Wind Speed': 7.4,
#   'Current Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 49.84,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 50.63,
#   'Humidity': 64,
#   'Cloudiness': 48,
#   'Wind Speed': 5.68,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 71.98,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Elbistan',
#   'Country': 'TR',
#   'Lat': 38.2059,
#   'Lng': 37.1983,
#   'Max Temp': 79.79,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 4.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 51.4,
#   'Humidity': 75,
#   'Cloudiness': 55,
#   'Wind Speed': 4.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Libreville',
#   'Country': 'GA',
#   'Lat': 0.3925,
#   'Lng': 9.4537,
#   'Max Temp': 75.9,
#   'Humidity': 81,
#   'Cloudiness': 32,
#   'Wind Speed': 10.54,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 54.59,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Current Description': 'few clouds'},
#  {'City': 'Misratah',
#   'Country': 'LY',
#   'Lat': 32.3754,
#   'Lng': 15.0925,
#   'Max Temp': 84.13,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 15.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 52.9,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 10.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bosaso',
#   'Country': 'SO',
#   'Lat': 11.2842,
#   'Lng': 49.1816,
#   'Max Temp': 92.34,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhangzhou',
#   'Country': 'CN',
#   'Lat': 24.5133,
#   'Lng': 117.6556,
#   'Max Temp': 82.33,
#   'Humidity': 88,
#   'Cloudiness': 55,
#   'Wind Speed': 2.59,
#   'Current Description': 'broken clouds'},
#  {'City': 'Palauig',
#   'Country': 'PH',
#   'Lat': 15.435,
#   'Lng': 119.9045,
#   'Max Temp': 80.51,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Current Description': 'light rain'},
#  {'City': 'Parbhani',
#   'Country': 'IN',
#   'Lat': 19.2667,
#   'Lng': 76.7833,
#   'Max Temp': 81.19,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 82,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 2.15,
#   'Current Description': 'clear sky'},
#  {'City': 'Ucluelet',
#   'Country': 'CA',
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 62.91,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'New Amsterdam',
#   'Country': 'GY',
#   'Lat': 6.25,
#   'Lng': -57.5167,
#   'Max Temp': 87.04,
#   'Humidity': 57,
#   'Cloudiness': 33,
#   'Wind Speed': 7.52,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 91.85,
#   'Humidity': 27,
#   'Cloudiness': 90,
#   'Wind Speed': 8.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mana',
#   'Country': 'GF',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 83.16,
#   'Humidity': 75,
#   'Cloudiness': 13,
#   'Wind Speed': 8.57,
#   'Current Description': 'few clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 49.5,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 77.4,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Kavaratti',
#   'Country': 'IN',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 81.09,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 22.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Joaquin',
#   'Country': 'US',
#   'Lat': 37.9333,
#   'Lng': -121.3011,
#   'Max Temp': 80.55,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Kotel',
#   'Country': 'BG',
#   'Lat': 42.8833,
#   'Lng': 26.45,
#   'Max Temp': 78.35,
#   'Humidity': 55,
#   'Cloudiness': 57,
#   'Wind Speed': 4.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Amahai',
#   'Country': 'ID',
#   'Lat': -3.3333,
#   'Lng': 128.9167,
#   'Max Temp': 76.59,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 2.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 44.31,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 8.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 53.76,
#   'Humidity': 57,
#   'Cloudiness': 77,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapiri Mposhi',
#   'Country': 'ZM',
#   'Lat': -13.9652,
#   'Lng': 28.6809,
#   'Max Temp': 62.37,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Kolpashevo',
#   'Country': 'RU',
#   'Lat': 58.3131,
#   'Lng': 82.9089,
#   'Max Temp': 59.22,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16,
#   'Current Description': 'light rain'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 53.67,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 82.38,
#   'Humidity': 65,
#   'Cloudiness': 25,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Atambua',
#   'Country': 'ID',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 70.02,
#   'Humidity': 89,
#   'Cloudiness': 80,
#   'Wind Speed': 4.88,
#   'Current Description': 'broken clouds'},
#  {'City': 'Qasigiannguit',
#   'Country': 'GL',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': 53.85,
#   'Humidity': 84,
#   'Cloudiness': 57,
#   'Wind Speed': 4.09,
#   'Current Description': 'broken clouds'},
#  {'City': 'Astana',
#   'Country': 'KZ',
#   'Lat': 51.1801,
#   'Lng': 71.446,
#   'Max Temp': 69.75,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 6.71,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Oistins',
#   'Country': 'BB',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 86.5,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 25.32,
#   'Current Description': 'few clouds'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 69.96,
#   'Humidity': 56,
#   'Cloudiness': 98,
#   'Wind Speed': 11.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 71.89,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'La Paz',
#   'Country': 'BO',
#   'Lat': -16.5,
#   'Lng': -68.15,
#   'Max Temp': 64.38,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 76.96,
#   'Humidity': 84,
#   'Cloudiness': 94,
#   'Wind Speed': 2.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Merauke',
#   'Country': 'ID',
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp': 75.96,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 13.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 70.75,
#   'Humidity': 77,
#   'Cloudiness': 64,
#   'Wind Speed': 14.76,
#   'Current Description': 'moderate rain'},
#  {'City': 'Kondinskoye',
#   'Country': 'RU',
#   'Lat': 59.6481,
#   'Lng': 67.41,
#   'Max Temp': 60.22,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 8.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palora',
#   'Country': 'EC',
#   'Lat': -1.7,
#   'Lng': -77.9333,
#   'Max Temp': 80.71,
#   'Humidity': 50,
#   'Cloudiness': 49,
#   'Wind Speed': 4.63,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Macia',
#   'Country': 'MZ',
#   'Lat': -25.0269,
#   'Lng': 33.0989,
#   'Max Temp': 67.62,
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 14.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 55.72,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 3.89,
#   'Current Description': 'clear sky'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 54.91,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kropotkin',
#   'Country': 'RU',
#   'Lat': 45.4375,
#   'Lng': 40.5756,
#   'Max Temp': 83.43,
#   'Humidity': 31,
#   'Cloudiness': 3,
#   'Wind Speed': 9.64,
#   'Current Description': 'clear sky'},
#  {'City': 'Vondrozo',
#   'Country': 'MG',
#   'Lat': -22.8167,
#   'Lng': 47.2833,
#   'Max Temp': 59.52,
#   'Humidity': 98,
#   'Cloudiness': 19,
#   'Wind Speed': 0.65,
#   'Current Description': 'few clouds'},
#  {'City': 'Malumfashi',
#   'Country': 'NG',
#   'Lat': 11.7853,
#   'Lng': 7.6218,
#   'Max Temp': 75.61,
#   'Humidity': 74,
#   'Cloudiness': 58,
#   'Wind Speed': 7.25,
#   'Current Description': 'broken clouds'},
#  {'City': 'Gold Coast',
#   'Country': 'AU',
#   'Lat': -28,
#   'Lng': 153.4333,
#   'Max Temp': 59,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 10.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 66.58,
#   'Humidity': 79,
#   'Cloudiness': 25,
#   'Wind Speed': 12.39,
#   'Current Description': 'light rain'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 52.74,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Kholodnyy',
#   'Country': 'RU',
#   'Lat': 62.7167,
#   'Lng': 147.95,
#   'Max Temp': 51.35,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 6.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Osakarovka',
#   'Country': 'KZ',
#   'Lat': 50.565,
#   'Lng': 72.5692,
#   'Max Temp': 60.53,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 4.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Madang',
#   'Country': 'PG',
#   'Lat': -5.2246,
#   'Lng': 145.7966,
#   'Max Temp': 76.44,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind Speed': 3.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shelburne',
#   'Country': 'CA',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 81.75,
#   'Humidity': 43,
#   'Cloudiness': 78,
#   'Wind Speed': 10.6,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 63.23,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 3.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oranjemund',
#   'Country': 'NA',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 53.69,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 26.49,
#   'Current Description': 'clear sky'},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 60.78,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 5.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Altamira',
#   'Country': 'BR',
#   'Lat': -3.2033,
#   'Lng': -52.2064,
#   'Max Temp': 88.7,
#   'Humidity': 50,
#   'Cloudiness': 73,
#   'Wind Speed': 3.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 62.89,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 11.92,
#   'Current Description': 'light rain'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 64.44,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 57.38,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 8.99,
#   'Current Description': 'light rain'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 78.84,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dahuk',
#   'Country': 'IQ',
#   'Lat': 36.8695,
#   'Lng': 42.994,
#   'Max Temp': 93.36,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 2.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Kadhan',
#   'Country': 'PK',
#   'Lat': 24.481,
#   'Lng': 68.9859,
#   'Max Temp': 82.49,
#   'Humidity': 82,
#   'Cloudiness': 41,
#   'Wind Speed': 18.32,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Owo',
#   'Country': 'NG',
#   'Lat': 7.1962,
#   'Lng': 5.5868,
#   'Max Temp': 71.06,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 7.81,
#   'Current Description': 'light rain'},
#  {'City': 'Wakkanai',
#   'Country': 'JP',
#   'Lat': 45.4094,
#   'Lng': 141.6739,
#   'Max Temp': 61.9,
#   'Humidity': 91,
#   'Cloudiness': 88,
#   'Wind Speed': 18.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 50.05,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 19.86,
#   'Current Description': 'clear sky'},
#  {'City': 'Korla',
#   'Country': 'CN',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 80.8,
#   'Humidity': 38,
#   'Cloudiness': 84,
#   'Wind Speed': 18.54,
#   'Current Description': 'broken clouds'},
#  {'City': 'Newcastle',
#   'Country': 'AU',
#   'Lat': -32.9272,
#   'Lng': 151.7765,
#   'Max Temp': 57.81,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Noumea',
#   'Country': 'NC',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 70,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 16.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vozhega',
#   'Country': 'RU',
#   'Lat': 60.4725,
#   'Lng': 40.2213,
#   'Max Temp': 57.58,
#   'Humidity': 76,
#   'Cloudiness': 76,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ahuimanu',
#   'Country': 'US',
#   'Lat': 21.4447,
#   'Lng': -157.8378,
#   'Max Temp': 80.31,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Auki',
#   'Country': 'SB',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 76.28,
#   'Humidity': 89,
#   'Cloudiness': 9,
#   'Wind Speed': 4.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Ulladulla',
#   'Country': 'AU',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 52.48,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 36.05,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 6.51,
#   'Current Description': 'few clouds'},
#  {'City': 'Pangai',
#   'Country': 'TO',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 77.11,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 49.77,
#   'Humidity': 62,
#   'Cloudiness': 16,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Yuzhno-Kurilsk',
#   'Country': 'RU',
#   'Lat': 44.0306,
#   'Lng': 145.8556,
#   'Max Temp': 58.57,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 12.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chyhyryn',
#   'Country': 'UA',
#   'Lat': 49.0838,
#   'Lng': 32.6555,
#   'Max Temp': 74.62,
#   'Humidity': 51,
#   'Cloudiness': 7,
#   'Wind Speed': 10.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 49.21,
#   'Humidity': 83,
#   'Cloudiness': 88,
# ...
#   'Country': 'ID',
#   'Lat': -2.6833,
#   'Lng': 111.6167,
#   'Max Temp': 72.07,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saran',
#   'Country': 'FR',
#   'Lat': 47.9501,
#   'Lng': 1.876,
#   'Max Temp': 88.83,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Nyrob',
#   'Country': 'RU',
#   'Lat': 60.733,
#   'Lng': 56.7202,
#   'Max Temp': 60.91,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Charters Towers',
#   'Country': 'AU',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 56.55,
#   'Humidity': 95,
#   'Cloudiness': 64,
#   'Wind Speed': 7.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pandaria',
#   'Country': 'IN',
#   'Lat': 22.2333,
#   'Lng': 81.4167,
#   'Max Temp': 80.96,
#   'Humidity': 75,
#   'Cloudiness': 91,
#   'Wind Speed': 5.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Praya',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 81.14,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Beira',
#   'Country': 'MZ',
#   'Lat': -19.8436,
#   'Lng': 34.8389,
#   'Max Temp': 69.89,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 56.93,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 48.47,
#   'Humidity': 77,
#   'Cloudiness': 19,
#   'Wind Speed': 7.76,
#   'Current Description': 'few clouds'},
#  {'City': 'Amudat',
#   'Country': 'UG',
#   'Lat': 1.95,
#   'Lng': 34.95,
#   'Max Temp': 69.98,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 3.67,
#   'Current Description': 'moderate rain'},
#  {'City': 'Sao Borja',
#   'Country': 'BR',
#   'Lat': -28.6606,
#   'Lng': -56.0044,
#   'Max Temp': 73.94,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 1.88,
#   'Current Description': 'clear sky'},
#  {'City': 'Dongsheng',
#   'Country': 'CN',
#   'Lat': 39.8161,
#   'Lng': 109.9776,
#   'Max Temp': 73.87,
#   'Humidity': 52,
#   'Cloudiness': 51,
#   'Wind Speed': 8.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Laki',
#   'Country': 'BG',
#   'Lat': 41.85,
#   'Lng': 24.8167,
#   'Max Temp': 75.36,
#   'Humidity': 83,
#   'Cloudiness': 73,
#   'Wind Speed': 2.84,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nikolsk',
#   'Country': 'RU',
#   'Lat': 53.7189,
#   'Lng': 46.0712,
#   'Max Temp': 60.21,
#   'Humidity': 76,
#   'Cloudiness': 5,
#   'Wind Speed': 5.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 75.33,
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 3.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Toshkivka',
#   'Country': 'UA',
#   'Lat': 48.7791,
#   'Lng': 38.579,
#   'Max Temp': 76.96,
#   'Humidity': 33,
#   'Cloudiness': 23,
#   'Wind Speed': 14.38,
#   'Current Description': 'few clouds'},
#  {'City': 'Antalaha',
#   'Country': 'MG',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 67.68,
#   'Humidity': 88,
#   'Cloudiness': 2,
#   'Wind Speed': 7.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Ambilobe',
#   'Country': 'MG',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 70.36,
#   'Humidity': 73,
#   'Cloudiness': 32,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dabola',
#   'Country': 'GN',
#   'Lat': 10.75,
#   'Lng': -11.1167,
#   'Max Temp': 77.22,
#   'Humidity': 89,
#   'Cloudiness': 83,
#   'Wind Speed': 1.03,
#   'Current Description': 'moderate rain'},
#  {'City': 'El Estor',
#   'Country': 'GT',
#   'Lat': 15.5333,
#   'Lng': -89.35,
#   'Max Temp': 79.07,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 2.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manzil Salim',
#   'Country': 'TN',
#   'Lat': 35.8567,
#   'Lng': 8.4765,
#   'Max Temp': 90.61,
#   'Humidity': 23,
#   'Cloudiness': 2,
#   'Wind Speed': 13.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Matara',
#   'Country': 'LK',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 77.41,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 12.5,
#   'Current Description': 'light rain'},
#  {'City': 'Zlobin',
#   'Country': 'HR',
#   'Lat': 45.2924,
#   'Lng': 14.6541,
#   'Max Temp': 74.5,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Kamenskiy',
#   'Country': 'RU',
#   'Lat': 50.8855,
#   'Lng': 45.488,
#   'Max Temp': 70.32,
#   'Humidity': 71,
#   'Cloudiness': 74,
#   'Wind Speed': 13.89,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tomatlan',
#   'Country': 'MX',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 93.92,
#   'Humidity': 45,
#   'Cloudiness': 98,
#   'Wind Speed': 1.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lohne',
#   'Country': 'DE',
#   'Lat': 52.6667,
#   'Lng': 8.2333,
#   'Max Temp': 69.19,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 9.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Umm Kaddadah',
#   'Country': 'SD',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 84.22,
#   'Humidity': 51,
#   'Cloudiness': 83,
#   'Wind Speed': 6.67,
#   'Current Description': 'moderate rain'},
#  {'City': 'Manakara',
#   'Country': 'MG',
#   'Lat': -22.1333,
#   'Lng': 48.0167,
#   'Max Temp': 67.46,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 6.96,
#   'Current Description': 'clear sky'},
#  {'City': 'Mecca',
#   'Country': 'SA',
#   'Lat': 21.4267,
#   'Lng': 39.8261,
#   'Max Temp': 92.28,
#   'Humidity': 28,
#   'Cloudiness': 21,
#   'Wind Speed': 4.41,
#   'Current Description': 'few clouds'},
#  {'City': 'Synya',
#   'Country': 'RU',
#   'Lat': 65.3718,
#   'Lng': 58.0387,
#   'Max Temp': 60.03,
#   'Humidity': 70,
#   'Cloudiness': 29,
#   'Wind Speed': 2.42,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Homer',
#   'Country': 'US',
#   'Lat': 59.6425,
#   'Lng': -151.5483,
#   'Max Temp': 59.04,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Louiseville',
#   'Country': 'CA',
#   'Lat': 46.2559,
#   'Lng': -72.9415,
#   'Max Temp': 79.95,
#   'Humidity': 53,
#   'Cloudiness': 8,
#   'Wind Speed': 14.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Guider',
#   'Country': 'CM',
#   'Lat': 9.9342,
#   'Lng': 13.9486,
#   'Max Temp': 78.82,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 5.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ariquemes',
#   'Country': 'BR',
#   'Lat': -9.9133,
#   'Lng': -63.0408,
#   'Max Temp': 97.36,
#   'Humidity': 22,
#   'Cloudiness': 3,
#   'Wind Speed': 3.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Kangaba',
#   'Country': 'ML',
#   'Lat': 11.9333,
#   'Lng': -8.4167,
#   'Max Temp': 82.24,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 4.59,
#   'Current Description': 'light rain'},
#  {'City': 'Lokoja',
#   'Country': 'NG',
#   'Lat': 7.8024,
#   'Lng': 6.743,
#   'Max Temp': 76.55,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'light rain'},
#  {'City': 'Riyadh',
#   'Country': 'SA',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 89.74,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 19.91,
#   'Current Description': 'light rain'},
#  {'City': 'Ransang',
#   'Country': 'PH',
#   'Lat': 8.9603,
#   'Lng': 117.5828,
#   'Max Temp': 78.46,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Current Description': 'light rain'},
#  {'City': 'Burgeo',
#   'Country': 'CA',
#   'Lat': 47.6167,
#   'Lng': -57.6152,
#   'Max Temp': 68.38,
#   'Humidity': 77,
#   'Cloudiness': 49,
#   'Wind Speed': 20.54,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kassala',
#   'Country': 'SD',
#   'Lat': 15.451,
#   'Lng': 36.4,
#   'Max Temp': 82.49,
#   'Humidity': 65,
#   'Cloudiness': 93,
#   'Wind Speed': 16.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saravan',
#   'Country': 'AM',
#   'Lat': 39.7196,
#   'Lng': 45.6483,
#   'Max Temp': 64.96,
#   'Humidity': 59,
#   'Cloudiness': 65,
#   'Wind Speed': 6.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Porto Novo',
#   'Country': 'BJ',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 76.82,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 12.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gao',
#   'Country': 'ML',
#   'Lat': 16.6362,
#   'Lng': 1.637,
#   'Max Temp': 104.43,
#   'Humidity': 12,
#   'Cloudiness': 44,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Victor Harbor',
#   'Country': 'AU',
#   'Lat': -35.5667,
#   'Lng': 138.6167,
#   'Max Temp': 49.68,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 14.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Porto Empedocle',
#   'Country': 'IT',
#   'Lat': 37.2934,
#   'Lng': 13.5264,
#   'Max Temp': 84.31,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 10.89,
#   'Current Description': 'clear sky'},
#  {'City': 'Senador Guiomard',
#   'Country': 'BR',
#   'Lat': -10.1522,
#   'Lng': -67.7392,
#   'Max Temp': 91.15,
#   'Humidity': 27,
#   'Cloudiness': 20,
#   'Wind Speed': 4.88,
#   'Current Description': 'few clouds'},
#  {'City': 'Tayu',
#   'Country': 'ID',
#   'Lat': -6.5397,
#   'Lng': 111.0518,
#   'Max Temp': 78.85,
#   'Humidity': 78,
#   'Cloudiness': 85,
#   'Wind Speed': 6.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coyah',
#   'Country': 'GN',
#   'Lat': 9.75,
#   'Lng': -13.4167,
#   'Max Temp': 79.45,
#   'Humidity': 85,
#   'Cloudiness': 97,
#   'Wind Speed': 5.82,
#   'Current Description': 'light rain'},
#  {'City': 'San Rafael',
#   'Country': 'AR',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 61.84,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 6.15,
#   'Current Description': 'clear sky'},
#  {'City': 'Taltal',
#   'Country': 'CL',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 62.92,
#   'Humidity': 71,
#   'Cloudiness': 8,
#   'Wind Speed': 6.67,
#   'Current Description': 'clear sky'},
#  {'City': 'Jega',
#   'Country': 'NG',
#   'Lat': 12.2175,
#   'Lng': 4.3792,
#   'Max Temp': 81.09,
#   'Humidity': 62,
#   'Cloudiness': 72,
#   'Wind Speed': 7.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Afzalgarh',
#   'Country': 'IN',
#   'Lat': 29.4,
#   'Lng': 78.6833,
#   'Max Temp': 76.26,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind Speed': 3.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lichinga',
#   'Country': 'MZ',
#   'Lat': -13.3128,
#   'Lng': 35.2406,
#   'Max Temp': 62.69,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Iskateley',
#   'Country': 'RU',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 64.63,
#   'Humidity': 56,
#   'Cloudiness': 51,
#   'Wind Speed': 14.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ust-Kuyga',
#   'Country': 'RU',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': 64.18,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Current Description': 'light rain'},
#  {'City': 'Sao Felipe',
#   'Country': 'BR',
#   'Lat': -14.8167,
#   'Lng': -41.3833,
#   'Max Temp': 90.84,
#   'Humidity': 23,
#   'Cloudiness': 7,
#   'Wind Speed': 2.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Ornskoldsvik',
#   'Country': 'SE',
#   'Lat': 63.2909,
#   'Lng': 18.7153,
#   'Max Temp': 68.95,
#   'Humidity': 64,
#   'Cloudiness': 47,
#   'Wind Speed': 9.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 77.7,
#   'Humidity': 68,
#   'Cloudiness': 95,
#   'Wind Speed': 3.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mongoumba',
#   'Country': 'CF',
#   'Lat': 3.6415,
#   'Lng': 18.5936,
#   'Max Temp': 70.03,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Akcakoca',
#   'Country': 'TR',
#   'Lat': 41.0866,
#   'Lng': 31.1162,
#   'Max Temp': 73.22,
#   'Humidity': 92,
#   'Cloudiness': 9,
#   'Wind Speed': 3.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Diebougou',
#   'Country': 'BF',
#   'Lat': 10.9667,
#   'Lng': -3.25,
#   'Max Temp': 82.89,
#   'Humidity': 69,
#   'Cloudiness': 87,
#   'Wind Speed': 4.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Colwyn Bay',
#   'Country': 'GB',
#   'Lat': 53.2948,
#   'Lng': -3.7267,
#   'Max Temp': 66.06,
#   'Humidity': 34,
#   'Cloudiness': 21,
#   'Wind Speed': 5.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Ugra',
#   'Country': 'RU',
#   'Lat': 54.7777,
#   'Lng': 34.3267,
#   'Max Temp': 60.37,
#   'Humidity': 75,
#   'Cloudiness': 85,
#   'Wind Speed': 3.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Noshiro',
#   'Country': 'JP',
#   'Lat': 40.2039,
#   'Lng': 140.0242,
#   'Max Temp': 74.5,
#   'Humidity': 88,
#   'Cloudiness': 73,
#   'Wind Speed': 4.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bantou',
#   'Country': 'CN',
#   'Lat': 26.2151,
#   'Lng': 117.4893,
#   'Max Temp': 77.09,
#   'Humidity': 85,
#   'Cloudiness': 45,
#   'Wind Speed': 1.54,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Zhigansk',
#   'Country': 'RU',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 60.62,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 8.5,
#   'Current Description': 'light rain'},
#  {'City': 'Lusambo',
#   'Country': 'CD',
#   'Lat': -4.9667,
#   'Lng': 23.45,
#   'Max Temp': 79.38,
#   'Humidity': 48,
#   'Cloudiness': 95,
#   'Wind Speed': 2.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Vitoria Do Palmar',
#   'Country': 'BR',
#   'Lat': -33.5189,
#   'Lng': -53.3681,
#   'Max Temp': 58.12,
#   'Humidity': 61,
#   'Cloudiness': 85,
#   'Wind Speed': 3.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kananga',
#   'Country': 'CD',
#   'Lat': -5.8958,
#   'Lng': 22.4178,
#   'Max Temp': 83.37,
#   'Humidity': 30,
#   'Cloudiness': 46,
#   'Wind Speed': 3.65,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Constantine',
#   'Country': 'DZ',
#   'Lat': 36.365,
#   'Lng': 6.6147,
#   'Max Temp': 94.41,
#   'Humidity': 22,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Ondjiva',
#   'Country': 'AO',
#   'Lat': -17.0667,
#   'Lng': 15.7333,
#   'Max Temp': 66.52,
#   'Humidity': 27,
#   'Cloudiness': 4,
#   'Wind Speed': 2.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 84.33,
#   'Humidity': 27,
#   'Cloudiness': 50,
#   'Wind Speed': 5.12,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pueblo Nuevo',
#   'Country': 'MX',
#   'Lat': 23.3833,
#   'Lng': -105.3833,
#   'Max Temp': 70.43,
#   'Humidity': 60,
#   'Cloudiness': 98,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Severo',
#   'Country': 'IT',
#   'Lat': 41.6897,
#   'Lng': 15.376,
#   'Max Temp': 85.6,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 6.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Kysyl-Syr',
#   'Country': 'RU',
#   'Lat': 63.8986,
#   'Lng': 122.7617,
#   'Max Temp': 63.73,
#   'Humidity': 85,
#   'Cloudiness': 98,
#   'Wind Speed': 4.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baturaja',
#   'Country': 'ID',
#   'Lat': -4.1333,
#   'Lng': 104.1667,
#   'Max Temp': 73.24,
#   'Humidity': 99,
#   'Cloudiness': 63,
#   'Wind Speed': 2.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Foix',
#   'Country': 'FR',
#   'Lat': 42.8333,
#   'Lng': 1.5833,
#   'Max Temp': 79.77,
#   'Humidity': 51,
#   'Cloudiness': 16,
#   'Wind Speed': 3.38,
#   'Current Description': 'few clouds'},
#  {'City': 'Luzino',
#   'Country': 'RU',
#   'Lat': 54.9481,
#   'Lng': 73.0353,
#   'Max Temp': 71.37,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95,
#   'Current Description': 'light rain'},
#  {'City': 'Pemangkat',
#   'Country': 'ID',
#   'Lat': 1.1667,
#   'Lng': 108.9667,
#   'Max Temp': 76.42,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 3.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Biltine',
#   'Country': 'TD',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 83.48,
#   'Humidity': 61,
#   'Cloudiness': 88,
#   'Wind Speed': 1.63,
#   'Current Description': 'overcast clouds'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Busselton      AU -33.6500  115.3333     58.03        76          71
# 1      Buala      SB  -8.1450  159.5921     79.70        82           5
# 2   Kedrovyy      RU  56.1667   91.8167     68.41        97          42
# 3     Avarua      CK -21.2078 -159.7750     73.45        68          20
# 4     Castro      BR -24.7911  -50.0119     70.21        38           0
# 5    Qaanaaq      GL  77.4840  -69.3632     45.52        57          10
# 6     Albany      US  42.6001  -73.9662     83.26        52          61
# 7     Atuona      PF  -9.8000 -139.0333     75.79        80          26
# 8    Ushuaia      AR -54.8000  -68.3000     42.46        65          75
# 9   Nakamura      JP  32.9833  132.9333     77.29        97          96
#
#    Wind Speed Current Description
# 0       19.62       broken clouds
# 1        8.77           clear sky
# 2        4.47    scattered clouds
# 3        6.91          few clouds
# 4        6.06           clear sky
# 5        3.74           clear sky
# 6        1.16       broken clouds
# 7       12.28          light rain
# 8        3.44       broken clouds
# 9        3.22     overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_id")
